# %%
# !pip install numpy opencv-python matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB 991.0 kB/s eta 0:00:39
#    ---------------------------------------- 0.3/38.6 MB 3.7 MB/s eta 0:00:11
#     --------------------------------------- 0.8/38.6 MB 6.0 MB/s eta 0:00:07
#     --------------------------------------- 0.9/38.6 MB 5.2 MB/s eta 0:00:08
#    - -------------------------------------- 1.1/38.6 MB 5.2 MB/s eta 0:00:08
#    - -------------------------------------- 1.3/38.6 MB 5.2 MB/s eta 0:00:08
#    - -------------------------------------- 1.7/38.6 MB 5.4 MB/s eta 0:00:07
#    -- ------------------------------------- 2.1/38.6 MB 5.8 MB/s eta 0:00:07
#    -- ------------------------------------- 2.3/38.6 MB 5.5 MB/s eta 0:00:07
#    -- ------------------------------------- 2.5/38.6 MB 5.8 MB/s eta 0:00:07
#    -- ------------------------------------- 2.5/38.6 MB 5.2 MB/s eta 0:00:07
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def convert_3d_to_floor_plan(image_path, output_path):
    
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Image at {image_path} could not be loaded.")
    
    
    edges = cv2.Canny(img, 50, 150, apertureSize=3)

    
    kernel = np.ones((5, 5), np.uint8)
    dilated_edges = cv2.dilate(edges, kernel, iterations=1)

    
    cv2.imwrite(output_path, dilated_edges)

    
    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    plt.title('Original Image')
    plt.imshow(img, cmap='gray')
    
    plt.subplot(1, 2, 2)
    plt.title('Floor Plan')
    plt.imshow(dilated_edges, cmap='gray')
    
    plt.show()

# %%
convert_3d_to_floor_plan("C:\\Users\\Teena Hirekerur\\OneDrive\\Desktop\\3D_image.png", 'floor_plan.png')

# %%
print(os.getcwd())  
print(os.listdir())
# Out:
# C:\Users\Teena Hirekerur
# ...
